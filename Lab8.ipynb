# %%
#1. Viết chương trình Python với thư viện NLTK để liệt kê các tên của copus.
import nltk.corpus
dir(nltk.corpus)
print("Tên scopus là:")
print(dir(nltk.corpus))
# Out:
# Tên scopus là:
# ...

# %%
#2. Viết chương trình Python với thư viện NLTK để liệt kê danh sách các stopword bằng các ngôn ngữ khác nhau
from nltk.corpus import stopwords
print (stopwords.fileids())
# Out:
# ['arabic', 'azerbaijani', 'bengali', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'turkish']

# %%
#3. Viết chương trình Python với thư viện NLTK để kiểm tra danh sách các stopword bằng các ngôn ngữ khác nhau.
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
result = set(stopwords.words('english'))
print("Danh sách stopword English:")
print(result)
print("Danh sách stopword Arabic:")
result = set(stopwords.words('arabic'))
print(result)
print("Danh sách stopword Azerbaijani:")
result = set(stopwords.words('azerbaijani'))
print(result)
print("Danh sách stopword Danish:")
result = set(stopwords.words('danish'))
print(result)
print("Danh sách stopword Dutch:")
result = set(stopwords.words('dutch'))
print(result)
print("Danh sách stopword Finnish:")
result = set(stopwords.words('finnish'))
print(result)
print("Danh sách stopword French:")
result = set(stopwords.words('french'))
print(result)
print("Danh sách stopword German:")
result = set(stopwords.words('german'))
print(result)
print("Danh sách stopword Greek:")
result = set(stopwords.words('greek'))
print(result)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Danh sách stopword English:
# ...

# %%
#Viết chương trình Python với thư viện NLTK để loại bỏ các stopword từ một văn bản đã cho
from nltk.corpus import stopwords
stoplist = stopwords.words('english')
text = '''
When going to school, there are many subjects; however I still like literature the most. First, literature plays an important role in both education and daily life. Literature is not limit to a subject to be learnt at school. Furthermore, this subject teaches human about several aspects of life. From the very first step, student learns to write, read as well as describe things and people. Moreover, literature teaches one to be a responsible citizen and likeable personality. Literature is more than a subject, it’s an art and it can be applied directly into life such as: journalism, editor. People are not born to learn this unique subject, it needs long time to exercise to master. Besides, when learning literature people not only know more works of art but also understand culture, tradition of each country. Literature is the mirror reflecting human and their lifestyle. Studying literature means learning the way to love and live a true life. All in all, with great benefits of literature, it is necessary for each society especially developing countries.
'''
print(text)
clean_word_list = [word for word in text.split() if word not in stoplist]
print("Sau khi loại bỏ stopword văn bản nói trên:")
print(clean_word_list)
# Out:
# When going to school, there are many subjects; however I still like literature the most. First, literature plays an important role in both education and daily life. Literature is not limit to a subject to be learnt at school. Furthermore, this subject teaches human about several aspects of life. From the very first step, student learns to write, read as well as describe things and people. Moreover, literature teaches one to be a responsible citizen and likeable personality. Literature is more than a subject, it’s an art and it can be applied directly into life such as: journalism, editor. People are not born to learn this unique subject, it needs long time to exercise to master. Besides, when learning literature people not only know more works of art but also understand culture, tradition of each country. Literature is the mirror reflecting human and their lifestyle. Studying literature means learning the way to love and live a true life. All in all, with great benefits of literature
# ...

# %%
#5. Viết chương trình Python với thư viện NLTK bỏ qua các stopword từ danh sách các stopword.
import nltk
from nltk.corpus import stopwords
result = set(stopwords.words('english'))
print("danh sách các stopwords English:")
print(result)
stop_words = set(stopwords.words('english')) - set(['he', 'all', 'an'])
print("Danh sách các stopwords mới bằng English:")
print (stop_words)
# Out:
# danh sách các stopwords English:
# ...

# %%
#6. Viết một chương trình Python với thư viện NLTK để tìm định nghĩa và ví dụ của một từ đã cho bằng WordNet từ Wikipedia,
from nltk.corpus import wordnet 
nltk.download('wordnet')
syns = wordnet.synsets("go")
print("Xác định từ :")
print(syns[0].definition())
print("Ví dụ về từ sử dụng:")
print(syns[0].examples())
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Xác định từ :
# a time for working (after which you will be relieved by someone else)
# Ví dụ về từ sử dụng:
# ["it's my go", 'a spell of work']

# %%
#7. Viết chương trình Python với thư viện NLTK để tìm tập hợp các từ đồng nghĩa và trái nghĩa của một từ nào đó
from nltk.corpus import wordnet
synonyms = []
antonyms = []

for syn in wordnet.synsets("Smart"):
    for i in syn.lemmas():
        synonyms.append(i.name())
        if i.antonyms():
            antonyms.append(i.antonyms()[0].name())
print("Tập hợp các từ đồng nghĩa:")
print(set(synonyms))
print("Tập hợp các từ trái nghĩa:")
print(set(antonyms))
# Out:
# Tập hợp các từ đồng nghĩa:
# {'ache', 'impertinent', 'smarting', 'sassy', 'bright', 'chic', 'voguish', 'fresh', 'hurt', 'saucy', 'overbold', 'wise', 'impudent', 'smart', 'smartness'}
# Tập hợp các từ trái nghĩa:
# {'stupid'}

# %%
#8. Viết chương trình Python với thư viện NLTK để có cái nhìn tổng quan về bộ tag, chi tiết của một tag cụ thể trong bộ tag và chi tiết về một số bộ tag liên quan, sử dụng biểu thức chính quy.
import nltk
nltk.download('tagsets')
print("Các thẻ tag:")
print(nltk.help.brown_tagset())
print("chi tiết thẻ cụ thể :")
print(nltk.help.brown_tagset(r'AP'))
print("Chi tiết về một số tags liên quan, sử dụng biểu thức chính quy:")
nltk.help.brown_tagset(r'WP*')
# Out:
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# Các thẻ tag:
# (: opening parenthesis
#     (
# ): closing parenthesis
#     )
# *: negator
#     not n't
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ? ; ! :
# :: colon
#     :
# ABL: determiner/pronoun, pre-qualifier
#     quite such rather
# ABN: determiner/pronoun, pre-quantifier
#     all half many nary
# ABX: determiner/pronoun, double conjunction or pre-quantifier
#     both
# AP: determiner/pronoun, post-determiner
#     many other next more last former little several enough most least only
#     very few fewer past same Last latter less single plenty 'nough lesser
#     certain various manye next-to-last particular final previous present
#     nuf
# AP$: determiner/pronoun, post-determiner, genitive
#     other's
# AP+AP: determiner/pronoun, post-determiner, hyphenated pair
#     many-much
# AT: article
# ...

# %%
#9. Viết chương trình Python với thư viện NLTK để so sánh sự giống nhau của hai danh từ đã cho.
from nltk.corpus import wordnet
print("So sánh hai danh từ coffee và coffe:")
n1 = wordnet.synset('coffee.n.01')
n2 = wordnet.synset('coffee.n.01')
print(n1.wup_similarity(n2))
# Out:
# So sánh hai danh từ coffee và coffe:
# 1.0

# %%
#10. Viết chương trình Python với thư viện NLTK để so sánh sự giống nhau của hai động từ đã cho.
from nltk.corpus import wordnet
print("So sánh hai động từ go và come:")
v1 = wordnet.synset('go.v.01')
v2 = wordnet.synset('come.v.01')
print(v1.wup_similarity(v2))
# Out:
# So sánh hai động từ go và come:
# 0.6666666666666666

# %%
#11. Viết chương trình Python với thư viện NLTK để tìm số lượng tên nam và nữ trong các tên
#kho ngữ liệu. In tên 10 nam và nữ đầu tiên. Lưu ý: Kho văn bản tên chứa tổng cộng khoảng
#2943 nam (male.txt) và 5001 nữ (Female.txt) tên. Kho được biên soạn bởi Kantrowitz, Ross.
from nltk.corpus import names 
nltk.download('names')
print("Số tên nam:")
print (len(names.words('male.txt')))
print("Số tên nữ:")
print (len(names.words('female.txt')))
male_names = names.words('male.txt')
female_names = names.words('female.txt')
print("10 tên nam đầu tiên:")
print (male_names[0:10])
print("10 tên nữ đầu tiên:")
print (female_names[0:10])
# Out:
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Package names is already up-to-date!
# Số tên nam:
# 2943
# Số tên nữ:
# 5001
# 10 tên nam đầu tiên:
# ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim']
# 10 tên nữ đầu tiên:
# ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale']

# %%
#12. Viết chương trình Python với thư viện NLTK để in 15 kết hợp ngẫu nhiên đầu tiên được gắn
#nhãn nam và được gắn nhãn tên nữ từ kho tên.
from nltk.corpus import names 
import random 
 
male_names = names.words('male.txt')
female_names = names.words('female.txt')
 
labeled_male_names = [(str(name), 'male') for name in male_names]
labeled_female_names = [(str(name), 'female') for name in female_names]

# Kết hợp tên nam và nữ đã gắn nhãn
labeled_all_names = labeled_male_names + labeled_female_names
 
# Ngẫu nhiên tên đã được kết hợp
random.shuffle(labeled_all_names)
 
print("15 tên đầu tiên được kết hợp ngẫu nhiên:")
print (labeled_all_names[:15])
# Out:
# 15 tên đầu tiên được kết hợp ngẫu nhiên:
# [('Milli', 'female'), ('Row', 'female'), ('Tiertza', 'female'), ('Andrei', 'female'), ('Guillemette', 'female'), ('Charlean', 'female'), ('Mauritz', 'male'), ('Stig', 'male'), ('Gerrilee', 'female'), ('Fredelia', 'female'), ('Delcine', 'female'), ('Goldi', 'female'), ('Warden', 'male'), ('Fabian', 'male'), ('Willow', 'female')]

# %%
#13. Viết chương trình Python với thư viện NLTK để trích xuất ký tự cuối cùng của tất cả các tên
#được gắn nhãn và tạo mảng mới với chữ cái cuối cùng của mỗi tên và nhãn được liên kết.
from nltk.corpus import names 
import random  
male_names = names.words('male.txt')
female_names = names.words('female.txt') 
labeled_male_names = [(str(name), 'male') for name in male_names]
labeled_female_names = [(str(name), 'female') for name in female_names]
# Kết hợp tên nam và nữ đã gắn nhãn
all_labeled_names = labeled_male_names + labeled_female_names 
feature_set = [(name[-1], gender) for (name, gender) in all_labeled_names]
print("15 tên được gán nhãn đầu tiên:") 
print((all_labeled_names[:15]))
print("Chữ cái cuối cùng của tất cả các tên được dán nhãn với nhãn liên kết và tạo mảng mới với chữ cái cuối cùng của mỗi tên và nhãn được liên kết:")
print((feature_set[:15]))
# Out:
# 15 tên được gán nhãn đầu tiên:
# [('Aamir', 'male'), ('Aaron', 'male'), ('Abbey', 'male'), ('Abbie', 'male'), ('Abbot', 'male'), ('Abbott', 'male'), ('Abby', 'male'), ('Abdel', 'male'), ('Abdul', 'male'), ('Abdulkarim', 'male'), ('Abdullah', 'male'), ('Abe', 'male'), ('Abel', 'male'), ('Abelard', 'male'), ('Abner', 'male')]
# Chữ cái cuối cùng của tất cả các tên được dán nhãn với nhãn liên kết và tạo mảng mới với chữ cái cuối cùng của mỗi tên và nhãn được liên kết:
# [('r', 'male'), ('n', 'male'), ('y', 'male'), ('e', 'male'), ('t', 'male'), ('t', 'male'), ('y', 'male'), ('l', 'male'), ('l', 'male'), ('m', 'male'), ('h', 'male'), ('e', 'male'), ('l', 'male'), ('d', 'male'), ('r', 'male')]
